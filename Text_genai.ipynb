# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.5/733.5 kB 14.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

# %%
GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

# %%
from google import genai

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

model = "gemini-3-flash-preview"
response = client.models.generate_content(
     model=model,
     contents = "Explain how text-to-video AI works in simple terms"
)
print(response.text)
# Out:
# Think of text-to-video AI as a super-advanced digital artist that has watched almost every video on the internet and memorized how the world works.
#
# To understand how it turns your words into a movie, you can break it down into three simple steps:
#
# ### 1. The "Translation" Step (Understanding)
# When you type a prompt like *"A golden retriever puppy running through a field of sunflowers,"* the AI doesn't just see letters. It translates those words into a mathematical "map."
#
# It knows that "golden retriever" looks like a yellow dog, "running" involves specific leg movements, and "sunflowers" are tall, yellow, and green. It connects your words to millions of images and videos it studied during its training.
#
# ### 2. The "Statue in the Marble" Step (Diffusion)
# Most video AI uses a process called **Diffusion**.
#
# Imagine a sculptor looking at a blurry, messy block of marble and "seeing" the statue inside. The AI starts with a screen full of **digital static** (like the "snow" on an old TV).
# *   It looks at that random noise and asks: *"Where can I see a puppy in this mess?"*
# *   It slowly "cleans" the noise, pixel by pixel, based on your prompt.
# *   After many rounds of cleaning, a clear image of a puppy appears.
#
# ### 3. The "Flipbook" Step (Adding Motion)
# This is the hardest part. A video is just a series of still pictures (frames) played very fast.
#
# If the AI just made 30 separate pictures of a puppy, it would look like a chaotic slideshow because the puppy would jump around randomly. To make it a **video**, the AI has to ensure **consistency**:
# *   It predicts what the puppy should look like 1/24th of a second later.
# *   It makes sure the ears flop in the right direction and the sunflowers stay in the same place.
# *   It uses "temporal logic" (the logic of time) to make sure gravity and movement look real.
#
# ### Summary: How it learns
# The AI is able to do this because it was trained on massive datasets of videos. By watching millions of clips, it learned:
# *   **Physics:** That a ball should fall down, not up.
# *   **Context:** That if a person is walking, their legs should swap positions.
# *   **Consistency:** That a red car shouldn't suddenly turn into a blue truck halfway through the scene.
#
# **In short: You provide the idea, the AI translates it into a concept, clears it out of a cloud of digital static, and then uses "math-based imagination" to guess how those pixels should move over time.**
